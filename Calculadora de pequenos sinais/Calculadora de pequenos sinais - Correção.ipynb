# %%
from tkinter import *
from tkinter import ttk

#   Cores

co0 = '#ffffff'    #branco
co1 = '#444466'    #preto
co2 = '#379936'    #verde
co3 = '#696969'    #cinza

janela = Tk()
janela.title('Calculadora de pequenos sinais')
janela.geometry('800x800')
janela.configure(bg=co0)


rows = 0
while rows<50:
    janela.rowconfigure(rows, weight =1)
    janela.columnconfigure(rows, weight=1)
    rows += 1

nb = ttk.Notebook(janela)    
nb.grid(row=1, column=0, columnspan=50, rowspan=49, sticky="NESW")

page1 = ttk.Frame(nb)
nb.add(page1, text='Autopolarização com RS JFET' )
page2 = ttk.Frame(nb)
nb.add(page2, text='Polarização com Divisor de Tensão - RE Desviado' )
page3 = ttk.Frame(nb)
nb.add(page3, text='Polarização com Divisor de Tensão - RE sem Desvio' )
page4 = ttk.Frame(nb)
nb.add(page4, text='Info' )


    
    
    

###############################----PAGINA 1----##########################################


#--------função calcular ----------


def calcular():
    
    Zi = float(e_RG.get()) 

    e_Zi['text'] = "{:.{}f}".format(Zi,0)
    
    RD =  float(e_RD.get())
    rd =  float(e_rd.get())

    Zo =  float((RD*rd)/(RD+rd))
    e_Zo['text'] = "{:.{}f}".format(Zo,1)
    
    gm= float(e_gm.get())*-1
    
    Av =  float(gm*((RD*rd)/(RD+rd)))
    e_Av['text'] = "{:.{}f}".format(Av,2)



#--------Divisão de tela---------

frame_cima = Frame(page1, width=800, height=50, bg=co0, pady=0, padx=0, relief='flat')
frame_cima.grid(row=0, column=0, sticky=NSEW)

frame_baixo = Frame(page1, width=800, height=180, bg=co0, pady=0, padx=0, relief='flat')
frame_baixo.grid(row=1, column=0, sticky=NSEW)

frame_resultados = Frame(page1, width=800, height=370, bg=co0, pady=0, padx=0, relief='flat')
frame_resultados.grid(row=2, column=0, sticky=NSEW)

#---------Configuração frame cima----------

app_nome = Label(frame_cima, text='Calculadora de pequenos sinais', width = 26, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 16 bold'),bg=co0, fg=co1)
app_nome.place(x=250, y=0)

app_linha = Label(frame_cima, text='', width = 800, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 1'),bg=co2, fg=co1)
app_linha.place(x=0, y=35)



#---------Configuração frame baixo----------

imagem = PhotoImage(file="JFET.png")

lb = Label(page1, image=imagem)

lb.place(x = 400, y =60)

    #---------VDD
l_VDD = Label(frame_baixo, text='Insira o VDD', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_VDD.grid(row=0, column=0, sticky=NSEW, pady=10, padx=3)

e_VDD = Entry(frame_baixo, width = 5, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_VDD.grid(row=0, column=1, sticky=NSEW, pady=10, padx=3)

unity_VDD = Label(frame_baixo, text='V', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_VDD.grid(row=0, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada RD
l_RD = Label(frame_baixo, text='Insira RD', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_RD.grid(row=1, column=0, sticky=NSEW, pady=10, padx=3)

e_RD = Entry(frame_baixo, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_RD.grid(row=1, column=1, sticky=NSEW, pady=10, padx=3)

unity_RD = Label(frame_baixo, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_RD.grid(row=1, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada rd
l_rd = Label(frame_baixo, text='Insira rd', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_rd.grid(row=2, column=0, sticky=NSEW, pady=10, padx=3)

e_rd = Entry(frame_baixo, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_rd.grid(row=2, column=1, sticky=NSEW, pady=10, padx=3)

unity_rd = Label(frame_baixo, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_rd.grid(row=2, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada RS
l_RS = Label(frame_baixo, text='Insira RS', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_RS.grid(row=3, column=0, sticky=NSEW, pady=10, padx=3)

e_RS = Entry(frame_baixo, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_RS.grid(row=3, column=1, sticky=NSEW, pady=10, padx=3)

unity_RS = Label(frame_baixo, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_RS.grid(row=3, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada RG
l_RG = Label(frame_baixo, text='Insira RG', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_RG.grid(row=4, column=0, sticky=NSEW, pady=10, padx=3)

e_RG = Entry(frame_baixo, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_RG.grid(row=4, column=1, sticky=NSEW, pady=10, padx=3)

unity_RG = Label(frame_baixo, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_RG.grid(row=4, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada gm
l_gm = Label(frame_baixo, text='Insira gm', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_gm.grid(row=5, column=0, sticky=NSEW, pady=10, padx=3)

e_gm = Entry(frame_baixo, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_gm.grid(row=5, column=1, sticky=NSEW, pady=10, padx=3)

#---------********** RESULTADO ***********---------------
    
#--------- Resultado Zi

l_Zi = Label(frame_resultados, text='Zi:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Zi.grid(row=0, column=0, sticky=NSEW, pady=10, padx=3)

e_Zi = Label(frame_resultados,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Zi.grid(row=0, column=1, sticky=NSEW, pady=10, padx=3)

unity_Zi = Label(frame_resultados, text='Ω ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Zi.grid(row=0, column=2, sticky=NSEW, pady=10, padx=3)

#--------- Resultado Zo

l_Zo = Label(frame_resultados, text='Zo:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Zo.grid(row=1, column=0, sticky=NSEW, pady=10, padx=3)

e_Zo = Label(frame_resultados,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Zo.grid(row=1, column=1, sticky=NSEW, pady=10, padx=3)

unity_Zo = Label(frame_resultados, text='Ω ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Zo.grid(row=1, column=2, sticky=NSEW, pady=10, padx=3)

#--------- Resultado Av

l_Av = Label(frame_resultados, text='Av:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Av.grid(row=2, column=0, sticky=NSEW, pady=10, padx=3)

e_Av = Label(frame_resultados,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Av.grid(row=2, column=1, sticky=NSEW, pady=10, padx=3)


b_calcular = Button(frame_baixo, command=calcular, text="Calcular", width = 34, height=1, overrelief=SOLID, relief= 'raised', anchor='center', font=('Ivy 10 bold'), bg=co2, fg=co0)
b_calcular.grid(row=6, column=0, sticky=NSEW, pady=30, padx=5, columnspan=10)


###############################----PAGINA 2----##########################################

#--------função calcular ----------


def calcular1():
    
    #variaveis
    VCC1 = float(e_VCC1.get())
    R11 = float(e_R11.get())
    beta1 = float(e_beta1.get())
    RE1 = float(e_RE1.get()) 
    RC1 = float(e_RC1.get())
    R21 = float(e_R21.get())
    ro1 = float(e_ro1.get())
    
    #expressoes
    Rth1 = float((R11*R21)/(R11+R21))
    Eth1 = float((R21*VCC1)/(R11+R21))
    Ib1 = float((Eth1 - 0.7)/(Rth1+(beta1+1)*RE1))
    Ie1 = float((beta1+1)*Ib1)
    re1 = float(0.026/Ie1)
    Zo1 = float(RC1)
    Av1 = float(-RC1/re1)
    Ai1 = float((beta1*Rth1)/(Rth1+(beta1*re1)))
    mult = float(beta1*re1)
    Req1 = float(Rth1)
    Zi1 = float((Req1*mult/(Req1+mult)))
       
    #show
    e_Zi1['text'] = "{:.{}f}".format(Zi1,2)
    e_Zo1['text'] = "{:.{}f}".format(Zo1,2)
    e_Av1['text'] = "{:.{}f}".format(Av1,2)
    e_Ai1['text'] = "{:.{}f}".format(Ai1,2)
    #e_re1['text'] = "{:.{}f}".format(re1,9)
    #e_Ie1['text'] = "{:.{}f}".format(Ie1,9)
    #e_Ib1['text'] = "{:.{}f}".format(Ib1,9)    
    #print(Rth)
        
#--------Divisão de tela---------

frame_cima1 = Frame(page2, width=800, height=50, bg=co0, pady=0, padx=0, relief='flat')
frame_cima1.grid(row=0, column=0, sticky=NSEW)

frame_baixo1 = Frame(page2, width=800, height=180, bg=co0, pady=0, padx=0, relief='flat')
frame_baixo1.grid(row=1, column=0, sticky=NSEW)

frame_resultados1 = Frame(page2, width=800, height=370, bg=co0, pady=0, padx=0, relief='flat')
frame_resultados1.grid(row=2, column=0, sticky=NSEW)

#---------Configuração frame cima----------

app_nome1 = Label(frame_cima1, text='Calculadora de pequenos sinais', width = 26, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 16 bold'),bg=co0, fg=co1)
app_nome1.place(x=250, y=0)

app_linha1 = Label(frame_cima1, text='', width = 800, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 1'),bg=co2, fg=co1)
app_linha1.place(x=0, y=35)


#---------Configuração frame baixo----------

imagem1 = PhotoImage(file="Polarização por divisor de tensão BJT.png")

lb1 = Label(page2, image=imagem1)

lb1.place(x = 350, y =60)

    #---------VCC
l_VCC1 = Label(frame_baixo1, text='Insira o VCC', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_VCC1.grid(row=0, column=0, sticky=NSEW, pady=10, padx=3)

e_VCC1 = Entry(frame_baixo1, width = 5, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_VCC1.grid(row=0, column=1, sticky=NSEW, pady=10, padx=3)

unity_VCC1 = Label(frame_baixo1, text='V', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_VCC1.grid(row=0, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada R1
l_R11 = Label(frame_baixo1, text='Insira R1', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_R11.grid(row=1, column=0, sticky=NSEW, pady=10, padx=3)

e_R11 = Entry(frame_baixo1, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_R11.grid(row=1, column=1, sticky=NSEW, pady=10, padx=3)

unity_R11 = Label(frame_baixo1, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_R11.grid(row=1, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada R2
l_R21 = Label(frame_baixo1, text='Insira R2', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_R21.grid(row=2, column=0, sticky=NSEW, pady=10, padx=3)

e_R21 = Entry(frame_baixo1, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_R21.grid(row=2, column=1, sticky=NSEW, pady=10, padx=3)

unity_R21 = Label(frame_baixo1, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_R21.grid(row=2, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada RC
    
l_RC1 = Label(frame_baixo1, text='Insira RC', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_RC1.grid(row=3, column=0, sticky=NSEW, pady=10, padx=3)

e_RC1 = Entry(frame_baixo1, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_RC1.grid(row=3, column=1, sticky=NSEW, pady=10, padx=3)

unity_RC1 = Label(frame_baixo1, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_RC1.grid(row=3, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada RE
l_RE1 = Label(frame_baixo1, text='Insira RE', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_RE1.grid(row=4, column=0, sticky=NSEW, pady=10, padx=3)

e_RE1 = Entry(frame_baixo1, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_RE1.grid(row=4, column=1, sticky=NSEW, pady=10, padx=3)

unity_RE1 = Label(frame_baixo1, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_RE1.grid(row=4, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada ro
l_ro1 = Label(frame_baixo1, text='Insira ro', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_ro1.grid(row=5, column=0, sticky=NSEW, pady=10, padx=3)

e_ro1 = Entry(frame_baixo1, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_ro1.grid(row=5, column=1, sticky=NSEW, pady=10, padx=3)

unity_ro1 = Label(frame_baixo1, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_ro1.grid(row=5, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada Beta
    
l_beta1 = Label(frame_baixo1, text='Insira β', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_beta1.grid(row=6, column=0, sticky=NSEW, pady=10, padx=3)

e_beta1 = Entry(frame_baixo1, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_beta1.grid(row=6, column=1, sticky=NSEW, pady=10, padx=3)

#_________________________________Resultados_____________________________________________
    
#--------------Zi

l_Zi1 = Label(frame_resultados1, text='Zi:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Zi1.grid(row=0, column=0, sticky=NSEW, pady=10, padx=3)

e_Zi1 = Label(frame_resultados1,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Zi1.grid(row=0, column=1, sticky=NSEW, pady=10, padx=3)

unity_Zi1 = Label(frame_resultados1, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Zi1.grid(row=0, column=2, sticky=NSEW, pady=10, padx=3)

#--------------Zo

l_Zo1 = Label(frame_resultados1, text='Zo:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Zo1.grid(row=1, column=0, sticky=NSEW, pady=10, padx=3)

e_Zo1 = Label(frame_resultados1,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Zo1.grid(row=1, column=1, sticky=NSEW, pady=10, padx=3)

unity_Zo1 = Label(frame_resultados1, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Zo1.grid(row=1, column=2, sticky=NSEW, pady=10, padx=3)

#--------------Av

l_Av1 = Label(frame_resultados1, text='Av:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Av1.grid(row=2, column=0, sticky=NSEW, pady=10, padx=3)

e_Av1 = Label(frame_resultados1,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Av1.grid(row=2, column=1, sticky=NSEW, pady=10, padx=3)

#--------------Ai

l_Ai1 = Label(frame_resultados1, text='Ai:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Ai1.grid(row=3, column=0, sticky=NSEW, pady=10, padx=3)

e_Ai1 = Label(frame_resultados1,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Ai1.grid(row=3, column=1, sticky=NSEW, pady=10, padx=3)

b_calcular1 = Button(frame_baixo1, command=calcular1, text="Calcular", width = 34, height=1, overrelief=SOLID, relief= 'raised', anchor='center', font=('Ivy 10 bold'), bg=co2, fg=co0)
b_calcular1.grid(row=7, column=0, sticky=NSEW, pady=30, padx=5, columnspan=10)

###############################----PAGINA 3----##########################################

#--------função calcular ----------


def calcular2():
    
    #variaveis
    VCC2 = float(e_VCC2.get())
    R12 = float(e_R12.get())
    beta2 = float(e_beta2.get())
    RE2 = float(e_RE2.get()) 
    RC2 = float(e_RC2.get())
    R22 = float(e_R22.get())
    #ro2 = float(e_ro2.get())
    
    #expressoes
    Rth2 = float((R12*R22)/(R12+R22))
    Eth2 = float((R22*VCC2)/(R12+R22))
    Ib2 = float((Eth2 - 0.7)/(Rth2+(beta2+1)*RE2))
    Ie2 = float((beta2+1)*Ib2) 
    re2 = float(0.026/Ie2)
    Zb2 = float(beta2*(re2+RE2))
    Zi2 = float((Rth2*Zb2)/(Rth2+Zb2))
    Zo2 = float(RC2) 
    Av2 = float(-RC2/RE2)
    Ai2 = float((beta2*Rth2)/(Rth2+Zb2))
    
    #show
    e_Zi2['text'] = "{:.{}f}".format(Zi2,2)
    e_Zo2['text'] = "{:.{}f}".format(Zo2,2)
    e_Av2['text'] = "{:.{}f}".format(Av2,2)
    e_Ai2['text'] = "{:.{}f}".format(Ai2,2)

#--------Divisão de tela---------

frame_cima2 = Frame(page3, width=800, height=50, bg=co0, pady=0, padx=0, relief='flat')
frame_cima2.grid(row=0, column=0, sticky=NSEW)

frame_baixo2 = Frame(page3, width=800, height=180, bg=co0, pady=0, padx=0, relief='flat')
frame_baixo2.grid(row=1, column=0, sticky=NSEW)

frame_resultados2 = Frame(page3, width=800, height=370, bg=co0, pady=0, padx=0, relief='flat')
frame_resultados2.grid(row=2, column=0, sticky=NSEW)

#---------Configuração frame cima----------

app_nome2 = Label(frame_cima2, text='Calculadora de pequenos sinais', width = 26, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 16 bold'),bg=co0, fg=co1)
app_nome2.place(x=250, y=0)

app_linha2 = Label(frame_cima2, text='', width = 800, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 1'),bg=co2, fg=co1)
app_linha2.place(x=0, y=35)


#---------Configuração frame baixo----------

imagem2 = PhotoImage(file="Polarização por divisor de tensão BJT.png")

lb2 = Label(page3, image=imagem2)

lb2.place(x = 350, y =60)

    #---------VCC
l_VCC2 = Label(frame_baixo2, text='Insira o VCC', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_VCC2.grid(row=0, column=0, sticky=NSEW, pady=10, padx=3)

e_VCC2 = Entry(frame_baixo2, width = 5, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_VCC2.grid(row=0, column=1, sticky=NSEW, pady=10, padx=3)

unity_VCC2 = Label(frame_baixo2, text='V', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_VCC2.grid(row=0, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada R1
l_R12 = Label(frame_baixo2, text='Insira R1', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_R12.grid(row=1, column=0, sticky=NSEW, pady=10, padx=3)

e_R12 = Entry(frame_baixo2, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_R12.grid(row=1, column=1, sticky=NSEW, pady=10, padx=3)

unity_R12 = Label(frame_baixo2, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_R12.grid(row=1, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada R2
l_R22 = Label(frame_baixo2, text='Insira R2', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_R22.grid(row=2, column=0, sticky=NSEW, pady=10, padx=3)

e_R22 = Entry(frame_baixo2, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_R22.grid(row=2, column=1, sticky=NSEW, pady=10, padx=3)

unity_R22 = Label(frame_baixo2, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_R22.grid(row=2, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada RC
    
l_RC2 = Label(frame_baixo2, text='Insira RC', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_RC2.grid(row=3, column=0, sticky=NSEW, pady=10, padx=3)

e_RC2 = Entry(frame_baixo2, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_RC2.grid(row=3, column=1, sticky=NSEW, pady=10, padx=3)

unity_RC2 = Label(frame_baixo2, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_RC2.grid(row=3, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada RE
l_RE2 = Label(frame_baixo2, text='Insira RE', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_RE2.grid(row=4, column=0, sticky=NSEW, pady=10, padx=3)

e_RE2 = Entry(frame_baixo2, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_RE2.grid(row=4, column=1, sticky=NSEW, pady=10, padx=3)

unity_RE2 = Label(frame_baixo2, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_RE2.grid(row=4, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada ro
l_ro2 = Label(frame_baixo2, text='Insira ro', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_ro2.grid(row=5, column=0, sticky=NSEW, pady=10, padx=3)

e_ro2 = Entry(frame_baixo2, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_ro2.grid(row=5, column=1, sticky=NSEW, pady=10, padx=3)

unity_ro2 = Label(frame_baixo2, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_ro2.grid(row=5, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Entrada Beta
    
l_beta2 = Label(frame_baixo2, text='Insira β', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_beta2.grid(row=6, column=0, sticky=NSEW, pady=10, padx=3)

e_beta2 = Entry(frame_baixo2, width = 15, relief = 'solid', font = ('Ivy 10 bold'),justify='center')
e_beta2.grid(row=6, column=1, sticky=NSEW, pady=10, padx=3)

#_________________________________Resultados_____________________________________________
    
#--------------Zi

l_Zi2 = Label(frame_resultados2, text='Zi:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Zi2.grid(row=0, column=0, sticky=NSEW, pady=10, padx=3)

e_Zi2 = Label(frame_resultados2,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Zi2.grid(row=0, column=1, sticky=NSEW, pady=10, padx=3)

unity_Zi2 = Label(frame_resultados2, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Zi2.grid(row=0, column=2, sticky=NSEW, pady=10, padx=3)

#--------------Zo

l_Zo2 = Label(frame_resultados2, text='Zo:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Zo2.grid(row=1, column=0, sticky=NSEW, pady=10, padx=3)

e_Zo2 = Label(frame_resultados2,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Zo2.grid(row=1, column=1, sticky=NSEW, pady=10, padx=3)

unity_Zo2 = Label(frame_resultados2, text='Ω', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Zo2.grid(row=1, column=2, sticky=NSEW, pady=10, padx=3)

#--------------Av

l_Av2 = Label(frame_resultados2, text='Av:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Av2.grid(row=2, column=0, sticky=NSEW, pady=10, padx=3)

e_Av2 = Label(frame_resultados2,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Av2.grid(row=2, column=1, sticky=NSEW, pady=10, padx=3)

#--------------Ai

l_Ai2 = Label(frame_resultados2, text='Ai:',width=2, height=1, padx=0, pady=0, relief='flat', anchor='w', font=('Ivy 10 bold'),bg=co0, fg=co1)
l_Ai2.grid(row=3, column=0, sticky=NSEW, pady=10, padx=3)

e_Ai2 = Label(frame_resultados2,text='---', width = 15, relief = 'solid', borderwidth=1, font = ('Ivy 10'),anchor='center', bg=co0, fg=co3)
e_Ai2.grid(row=3, column=1, sticky=NSEW, pady=10, padx=3)



b_calcular2 = Button(frame_baixo2, command=calcular2, text="Calcular", width = 34, height=1, overrelief=SOLID, relief= 'raised', anchor='center', font=('Ivy 10 bold'), bg=co2, fg=co0)
b_calcular2.grid(row=7, column=0, sticky=NSEW, pady=30, padx=5, columnspan=10)

###############################----CRÉDITO----##########################################


#--------Divisão de tela---------

frame_cima3 = Frame(page4, width=800, height=50, bg=co0, pady=0, padx=0, relief='flat')
frame_cima3.grid(row=0, column=0, sticky=NSEW)

frame_baixo3 = Frame(page4, width=800, height=180, bg=co0, pady=0, padx=0, relief='flat')
frame_baixo3.grid(row=1, column=0, sticky=NSEW)

frame_resultados3 = Frame(page4, width=800, height=370, bg=co0, pady=0, padx=0, relief='flat')
frame_resultados3.grid(row=2, column=0, sticky=NSEW)

#---------Configuração frame cima----------

app_nome3 = Label(frame_cima3, text='INFORMAÇÕES', width = 26, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 16 bold'),bg=co0, fg=co1)
app_nome3.place(x=250, y=0)

app_linha3 = Label(frame_cima3, text='', width = 800, height = 1, padx=0, relief = 'flat', anchor='center', font = ('Ivy 1'),bg=co2, fg=co1)
app_linha3.place(x=0, y=35)



#---------Configuração frame baixo----------

imagem3 = PhotoImage(file="if.png")

lb3 = Label(page4, image=imagem3)

lb3.place(x = 330, y =400)

    #---------Professor
l_Professor = Label(frame_baixo3, text='Professor: ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_Professor.grid(row=0, column=0, sticky=NSEW, pady=10, padx=3)


unity_Professor = Label(frame_baixo3, text='Andre Ricardo Borsato', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Professor.grid(row=0, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Disciplina
l_Professor1 = Label(frame_baixo3, text='Disciplina: ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_Professor1.grid(row=1, column=0, sticky=NSEW, pady=10, padx=3)


unity_Professor1 = Label(frame_baixo3, text='Eletrônica Analógica 2', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_Professor1.grid(row=1, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Aluno
l_aluno1 = Label(frame_baixo3, text='Aluno: ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_aluno1.grid(row=2, column=0, sticky=NSEW, pady=10, padx=3)


unity_aluno1 = Label(frame_baixo3, text='Marcio Rafael Buzoli', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_aluno1.grid(row=2, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Aluno
l_aluno2 = Label(frame_baixo3, text='Aluno: ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_aluno2.grid(row=3, column=0, sticky=NSEW, pady=10, padx=3)


unity_aluno2 = Label(frame_baixo3, text='Gabriel Luiz de Oliveira Pereira', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_aluno2.grid(row=3, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Aluno
l_aluno3 = Label(frame_baixo3, text='Aluno: ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_aluno3.grid(row=4, column=0, sticky=NSEW, pady=10, padx=3)


unity_aluno3 = Label(frame_baixo3, text='João Pedro Tosi', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_aluno3.grid(row=4, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Aluno
l_aluno3 = Label(frame_baixo3, text='Aluno: ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_aluno3.grid(row=5, column=0, sticky=NSEW, pady=10, padx=3)


unity_aluno3 = Label(frame_baixo3, text='João Octávio Rossato Telles', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_aluno3.grid(row=5, column=3, sticky=NSEW, pady=10, padx=3)

    #---------Material
l_material = Label(frame_baixo3, text='Material de apoio: ', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
l_material.grid(row=6, column=0, sticky=NSEW, pady=10, padx=3)


unity_material = Label(frame_baixo3, text='Dispositivos eletrônicos e teoria de circuitos', height = 1, padx=0, relief = 'flat', anchor='w', font = ('Ivy 10 bold'),bg=co0, fg=co1)
unity_material.grid(row=6, column=3, sticky=NSEW, pady=10, padx=3)

janela.mainloop()
